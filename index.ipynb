# %% [markdown]
# # Yelp API - Lab
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works and some basic Folium visualizations, it's time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and perform data analysis on the data returned
# * Perform pagination to retrieve troves of data!
# * Create a simple geographical system on to view information about selected businesses, at a given location.
#
# ## Problem Introduction
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retrieving 50 at a time. Processes such as these are often referred to as pagination.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a DataFrame (for further exploration) and create a map using Folium to visualize the results geographically.
#
# ## Part I - Make the Initial Request
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you, but make the request below.

# %%
import requests
import json

def get_keys(path):
    with open(path) as f:
        return json.load(f)

keys = get_keys('/Users/rlathbury/.secret/yelp_api.json')
api_key = keys["api_key"]

url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer {}'.format(api_key),}
url_params = {
    'term': 'coffee',
    'location': 'Philadelphia',
}
response = requests.get(url, headers=headers, params=url_params)
print(response.text)
# Out:
# {"businesses": [{"id": "oqbhVgliVJH-iRa3AnD-3A", "alias": "elixr-coffee-roasters-philadelphia-3", "name": "Elixr Coffee Roasters", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/KTq-mLDwVF9vmObl8H3Rsw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/elixr-coffee-roasters-philadelphia-3?adjust_creative=UuFVylLTLLnX5X6mtkfFzA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UuFVylLTLLnX5X6mtkfFzA", "review_count": 748, "categories": [{"alias": "coffeeroasteries", "title": "Coffee Roasteries"}, {"alias": "cafes", "title": "Cafes"}], "rating": 4.5, "coordinates": {"latitude": 39.9493333402848, "longitude": -75.1667326511781}, "transactions": [], "price": "$", "location": {"address1": "207 S Sydenham St", "address2": "", "address3": "", "city": "Philadelphia", "zip_code": "19102", "country": "US", "state": "PA", "display_address": ["207 S Sydenham St", "Philadelphia, PA 19102"]}, "phone": "", "display_phone": "", "distance": 624.4594152381294}, {"id": "Kt4NZ9IXvRCHI8qvV0h8qg", "alias": "peddler-coffee-philadelphia", "name": "Peddler Coffee", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/YeB63JYAQzjR9uPHzc704Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/peddler-coffee-philadelphia?adjust_creative=UuFVylLTLLnX5X6mtkfFzA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UuFVylLTLLnX5X6mtkfFzA", "review_count": 122, "categories": [{"alias": "coffeeroasteries", "title": "Coffee Roasteries"}], "rating": 4.5, "coordinates": {"latitude": 39.9582863310464, "longitude": -75.174281045892}, "transactions": [], "price": "$$", "location": {"address1": "2100 Spring St", "address2": "", "address3": "", "city": "Philadelphia", "zip_code": "19103", "country": "US", "state": "PA", "display_address": ["2100 Spring St", "Philadelphia, PA 19103"]}, "phone": "", "display_phone": "", "distance": 565.3779067259144}, {"id": "49Gyz-LD9MxTh1yzbYiOhw", "alias": "menagerie-coffee-philadelphia", "name": "Menagerie Coffee", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/uE0l5C56lBWDN5YwG2eTDw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/menagerie-coffee-philadelphia?adjust_creative=UuFVylLTLLnX5X6mtkfFzA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UuFVylLTLLnX5X6mtkfFzA", "review_count": 340, "categories": [{"alias": "coffee", "title": "Coffee & Tea"}], "rating": 4.5, "coordinates": {"latitude": 39.9496803, "longitude": -75.1459808}, "transactions": [], "price": "$", "location": {"address1": "18 S 3rd St", "address2": "", "address3": "", "city": "Philadelphia", "zip_code": "19106", "country": "US", "state": "PA", "display_address": ["18 S 3rd St", "Philadelphia, PA 19106"]}, "phone": "", "display_phone": "", "distance": 2203.192314042549}, {"id": "uqc5jOWOiPLTPibyy1yI4g", "alias": "vernick-coffee-bar-philadelphia", "name": "Vernick Coffee Bar", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/BVOMWJWTTlnZWd7UD5Eo9A/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/vernick-coffee-bar-philadelphia?adjust_creative=UuFVylLTLLnX5X6mtkfFzA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=UuFVylLTLLnX5X6mtkfFzA", "review_count": 28, "categories": [{"alias": "coffee", "title": "Coffee & Tea"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}, {"alias": "newamerican", "title": "American (New)"}], "rating": 4.5, "coordinates": {"latitude": 39.955061, "longitude": -75.170196}, "transactions": [], "price": "$$", "location": {"address1": "1800 Arch St", "address2": "Fl 2", "address3": "Comcast Technology Center", "city": "Philadelphia", "zip_code": "19103", "country": "US", "state": "PA", "display_address": ["1800 Arch St", "Fl 2", "Comcast Technology Center", "Philadelphia, PA 19103"]}, "phone": "+12154195052", "display_phone": "(215) 419-5052", "distance": 166.13060115137787}, {"id": "e4MoozYGqe_rb4_ZC1rYMQ", "alias": "nook-bakery-and-coffee-bar-philadelphia", "name": "Nook Bakery & Coffee Bar" ...

# %% [markdown]
# ## Pagination
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data. Your final goal will be to reformat the data concerning the businesses themselves into a pandas DataFrame from the json objects.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %%
import pandas as pd
import time

results = []
count = 0
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer {}'.format(api_key),}
url_params = {
    'term': 'coffee',
    'location': 'Philadelphia',
    'limit': 50
}
while count < response.json()['total'] and count < 1000:
    url_params['offset'] = count
    result = requests.get(url, headers=headers, params=url_params)
    try:
        results.append(pd.DataFrame(result.json()['businesses']))
        time.sleep(2)
        count += 50
    except:
        print(result.text)
        break

# %%
df = pd.concat(results, ignore_index=True)
df.head()
# Out:
#                                      alias  \
# 0     elixr-coffee-roasters-philadelphia-3
# 1              peddler-coffee-philadelphia
# 2            menagerie-coffee-philadelphia
# 3          vernick-coffee-bar-philadelphia
# 4  nook-bakery-and-coffee-bar-philadelphia
#
#                                           categories  \
# 0  [{'alias': 'coffeeroasteries', 'title': 'Coffe...
# 1  [{'alias': 'coffeeroasteries', 'title': 'Coffe...
# 2     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 3  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 4  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 39.9493333402848, 'longitude': -7...
# 1  {'latitude': 39.9582863310464, 'longitude': -7...
# 2  {'latitude': 39.9496803, 'longitude': -75.1459...
# 3   {'latitude': 39.955061, 'longitude': -75.170196}  (215) 419-5052
# 4  {'latitude': 39.952725, 'longitude': -75.1729016}  (215) 496-9033
#
#       distance                      id  \
# 0   624.459415  oqbhVgliVJH-iRa3AnD-3A
# 1   565.377907  Kt4NZ9IXvRCHI8qvV0h8qg
# 2  2203.192314  49Gyz-LD9MxTh1yzbYiOhw
# 3   166.130601  uqc5jOWOiPLTPibyy1yI4g
# 4   186.451973  e4MoozYGqe_rb4_ZC1rYMQ
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/KTq-mL...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/YeB63J...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/uE0l5C...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/BVOMWJ...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/iIzFEs...      False
#
#                                             location  \
# 0  {'address1': '207 S Sydenham St', 'address2': ...
# 1  {'address1': '2100 Spring St', 'address2': '',...
# 2  {'address1': '18 S 3rd St', 'address2': '', 'a...
# 3  {'address1': '1800 Arch St', 'address2': 'Fl 2...
# 4  {'address1': '15 S 20th St', 'address2': None,...
#
#                        name         phone price  rating  review_count  \
# 0     Elixr Coffee Roasters                   $     4.5           748
# 1            Peddler Coffee                  $$     4.5           122
# 2          Menagerie Coffee                   $     4.5           340
# 3        Vernick Coffee Bar  +12154195052    $$     4.5            28
# 4  Nook Bakery & Coffee Bar  +12154969033     $     4.5           276
#
#          transactions                                                url
# 0                  []  https://www.yelp.com/biz/elixr-coffee-roasters...
# 1                  []  https://www.yelp.com/biz/peddler-coffee-philad...
# 2                  []  https://www.yelp.com/biz/menagerie-coffee-phil...
# 3                  []  https://www.yelp.com/biz/vernick-coffee-bar-ph...
# 4  [delivery, pickup]  https://www.yelp.com/biz/nook-bakery-and-coffe...

# %% [markdown]
# ## Exploratory Analysis
#
# Take the restaurants from the previous question and do an initial exploratory analysis. At minimum, this should include looking at the distribution of features such as price, rating and number of reviews as well as the relations between these dimensions.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(df.rating)

# %%
sns.distplot(df.review_count)

# %%
df.price = df.price.fillna(0)
prices = {0: 0, '$':1, '$$': 2, '$$$': 3, '$$$$': 4}
df.price = df.price.map(prices)
sns.distplot(df.price)

# %%
df_analysis = df[['price','rating','review_count']]
pd.plotting.scatter_matrix(df_analysis, figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2300de80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2310ac50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a231a9208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a231d1780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a231f9cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a232292b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a23252828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2327cdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2327ce10>]],
#       dtype=object)

# %% [markdown]
# ## Mapping
#
# Look at the initial Yelp example and try and make a map using Folium of the restaurants you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.

# %%
import folium

lat = 39.9526
long = -75.1652
yelp_map = folium.Map([lat, long], zoom_start=13)

for row in df.index:
    try:
        lat_long = df.coordinates[row]
        lat = lat_long['latitude']
        long = lat_long['longitude']
        name = df.name[row]
        price = df.price[row]
        rating = df.rating[row]
        popup_text = '{}\nPrice: {}\nRating: {}'.format(name, price, rating)
        popup = folium.Popup(popup_text, parse_html=True)
        marker = folium.Marker(location=[lat, long], popup=popup)
        marker.add_to(yelp_map)
    except:
        print('error on row {}'.format(row))
yelp_map
# Out:
# error on row 133
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you synthesized your skills for the day, making multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice map visual to display the results! Well done!
